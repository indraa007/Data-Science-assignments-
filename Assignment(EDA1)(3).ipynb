# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Cardiotocographic.csv')
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.tail()
# Out:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.0  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.0  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2121  25.000000   7.2   40.0       0.0  2.000000
# 2122  22.000000   7.1   66.0       1.0  2.000000
# 2123  20.000000   6.1   67.0       1.0  1.990464
# 2124  27.000000   7.0   66.0       1.0  2.000000
# 2125  35.857183   5.0   42.0       0.0  1.000000

# %%
df.isnull()
# Out:
#          LB     AC     FM     UC     DL     DS     DP   ASTV   MSTV   ALTV  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2121  False  False  False  False  False  False  False  False  False  False
# 2122  False  False  False  False  False  False  False  False  False  False
# 2123  False  False  False  False  False  False  False  False  False  False
# 2124  False  False  False  False  False  False  False  False  False  False
# 2125  False  False  False  False  False  False  False  False  False  False
#
#        MLTV  Width  Tendency    NSP
# ...

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2121    False
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# Length: 2126, dtype: bool

# %%
df.dropna()
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.duplicated().sum()
# Out:
# 2

# %%
mean=df.mean()
mean
# Out:
# LB          133.343598
# AC            0.003219
# FM            0.009894
# UC            0.004391
# DL            0.001895
# DS            0.000003
# DP            0.000175
# ASTV         46.995984
# MSTV          1.364378
# ALTV         10.285964
# MLTV          8.284887
# Width        70.429260
# Tendency      0.316371
# NSP           1.304507
# dtype: float64

# %%
median=df.median()
median
# Out:
# LB          133.000000
# AC            0.001634
# FM            0.000000
# UC            0.004484
# DL            0.000000
# DS            0.000000
# DP            0.000000
# ASTV         49.000000
# MSTV          1.200000
# ALTV          0.000000
# MLTV          7.400000
# Width        67.000000
# Tendency      0.000000
# NSP           1.000000
# dtype: float64

# %%
mode=df['ASTV'].mode()
mode
# Out:
# 0    65.0
# Name: ASTV, dtype: float64

# %%
df['LB']=df['LB'].fillna(133.34358)
df['AC']=df['AC'].fillna(0.001634)
df['DS']=df['DS'].fillna(0.000003)
df['DP']=df['DP'].fillna(0)
df['MLTV']=df['MLTV'].fillna(8.284887)
df['Width']=df['Width'].fillna(67)
df['Tendency']=df['Tendency'].fillna(0.316371)
df['NSP']=df['NSP'].fillna(1)

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df1=df.drop_duplicates(ignore_index=True)
df1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2119  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2120  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2121  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2123  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2119  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2120  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2121  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2123  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# # Removing Outliers:-

# %%
Q1=df1['LB'].quantile(0.25)
Q1
# Out:
# 126.0

# %%
Q3=df1['LB'].quantile(0.75)
Q3
# Out:
# 140.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 14.0

# %%
lower=Q1-1.5*IQR
lower
# Out:
# 105.0

# %%
upper=Q3+1.5*IQR
upper
# Out:
# 161.0

# %%
df1.boxplot('LB',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
outliers=df1[(df1.LB<lower)| (df1.LB>upper)]
outliers
# Out:
#               LB        AC        FM        UC        DL        DS        DP  \
# 134    52.000000  0.001590  0.000000  0.029851  0.000000  0.000000  0.000003
# 411   214.000000  0.000000  0.000000  0.001595  0.001595  0.000000  0.000000
# 610   214.000000  0.002469  0.002469  0.002469  0.000000  0.000004  0.000000
# 612   214.000000  0.005181  0.012953  0.002591  0.000000  0.000000  0.000000
# 785    52.000000  0.000834  0.013344  0.000000  0.000000  0.000000  0.000000
# 1027   51.842487  0.009485  0.000000  0.005420  0.002710  0.000005  0.000000
# 1103  214.000000  0.006972  0.000000  0.002960  0.000000  0.000000  0.000000
# 1405  214.000000  0.005068  0.000000  0.001689  0.000000  0.000000  0.000000
# 1502  214.000000  0.006189  0.000000  0.006189  0.000000  0.000000  0.000000
# 1832   52.188547  0.000000  0.001043  0.003128  0.007299  0.000000  0.000000
#
#            ASTV      MSTV  ALTV  MLTV      Width  Tendency     NSP
# ...

# %%
outliers.boxplot('LB',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
df1.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.063413  0.018808 -0.166642 -0.126557 -0.005439
# AC       -0.063413  1.000000  0.009743  0.071313 -0.093581 -0.033088
# FM        0.018808  0.009743  1.000000 -0.053386  0.009641  0.029893
# UC       -0.166642  0.071313 -0.053386  1.000000  0.189737 -0.006939
# DL       -0.126557 -0.093581  0.009641  0.189737  1.000000  0.058432
# DS       -0.005439 -0.033088  0.029893 -0.006939  0.058432  1.000000
# DP       -0.047716 -0.083350  0.121434  0.070144  0.144631  0.004274
# ASTV      0.241666 -0.231086 -0.032838 -0.182379 -0.069907  0.008414
# MSTV     -0.169224  0.133215  0.017061  0.189685  0.410216  0.016089
# ALTV      0.210672 -0.269967 -0.012005 -0.227881 -0.187275 -0.004411
# MLTV     -0.003225 -0.104593 -0.006157 -0.048754 -0.164941  0.034366
# Width    -0.118372  0.234534  0.097204  0.106474  0.408340  0.040827
# Tendency  0.237112  0.031876 -0.018408 -0.066950 -0.023759 -0.015408
# ...

# %%
df1['LB'].corr
# Out:
# <bound method Series.corr of 0       120.000000
# 1       132.000000
# 2       133.000000
# 3       134.000000
# 4       131.948232
#            ...
# 2119    140.000000
# 2120    140.000000
# 2121    140.000000
# 2122    140.000000
# 2123    142.000000
# Name: LB, Length: 2124, dtype: float64>

# %%
df1.cov()
# Out:
#                   LB            AC            FM            UC            DL  \
# LB        125.717831 -3.110034e-03  1.424982e-02 -6.241368e-03 -4.744815e-03
# AC         -0.003110  1.913295e-05  2.879547e-06  1.041976e-06 -1.368717e-06
# FM          0.014250  2.879547e-06  4.565813e-03 -1.204979e-05  2.178340e-06
# UC         -0.006241  1.041976e-06 -1.204979e-05  1.115817e-05  2.119246e-06
# DL         -0.004745 -1.368717e-06  2.178340e-06  2.119246e-06  1.118066e-05
# DS         -0.000009 -2.039241e-08  2.846030e-07 -3.265710e-09  2.752962e-08
# DP         -0.000447 -3.048532e-07  6.861113e-06  1.959195e-07  4.043786e-07
# ASTV       50.975213 -1.901557e-02 -4.174298e-02 -1.146085e-02 -4.397434e-03
# MSTV       -2.227709  6.841396e-04  1.353540e-03  7.439234e-04  1.610443e-03
# ALTV       50.107383 -2.504941e-02 -1.720682e-02 -1.614733e-02 -1.328338e-02
# MLTV       -0.279710 -3.539437e-03 -3.218501e-03 -1.259922e-03 -4.266813e-03
# ...

# %%
df1.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.063413  0.018808 -0.166642 -0.126557 -0.005439
# AC       -0.063413  1.000000  0.009743  0.071313 -0.093581 -0.033088
# FM        0.018808  0.009743  1.000000 -0.053386  0.009641  0.029893
# UC       -0.166642  0.071313 -0.053386  1.000000  0.189737 -0.006939
# DL       -0.126557 -0.093581  0.009641  0.189737  1.000000  0.058432
# DS       -0.005439 -0.033088  0.029893 -0.006939  0.058432  1.000000
# DP       -0.047716 -0.083350  0.121434  0.070144  0.144631  0.004274
# ASTV      0.241666 -0.231086 -0.032838 -0.182379 -0.069907  0.008414
# MSTV     -0.169224  0.133215  0.017061  0.189685  0.410216  0.016089
# ALTV      0.210672 -0.269967 -0.012005 -0.227881 -0.187275 -0.004411
# MLTV     -0.003225 -0.104593 -0.006157 -0.048754 -0.164941  0.034366
# Width    -0.118372  0.234534  0.097204  0.106474  0.408340  0.040827
# Tendency  0.237112  0.031876 -0.018408 -0.066950 -0.023759 -0.015408
# ...

# %%
Q1=df1['ALTV'].quantile(0.25)
Q1
# Out:
# 0.0

# %%
Q3=df1['ALTV'].quantile(0.75)
Q3
# Out:
# 11.0

# %%
IQR= Q3-Q1
IQR
# Out:
# 11.0

# %%
lower=Q1-1.5*IQR
lower
# Out:
# -16.5

# %%
upper=Q3+1.5*IQR
upper
# Out:
# 27.5

# %%
df1.boxplot('ALTV',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
outliers2=df1[(df1.ALTV<lower)| (df1.ALTV>upper)]
outliers2
# Out:
#          LB        AC        FM        UC        DL   DS   DP  ASTV      MSTV  \
# 0     120.0  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0  0.500000
# 24    128.0  0.000000  0.000000  0.003311  0.000091  0.0  0.0  86.0  0.305801
# 25    124.0  0.000000  0.000000  0.000000 -0.000035  0.0  0.0  86.0  0.300000
# 27    124.0  0.000000  0.000000  0.000000  0.000000  0.0  0.0  87.0  0.200000
# 53    150.0  0.000000  0.000834  0.000000  0.000834  0.0  0.0  61.0  0.500000
# ...     ...       ...       ...       ...       ...  ...  ...   ...       ...
# 2104  136.0  0.000000  0.001096  0.007675  0.000000  0.0  0.0  78.0  0.400000
# 2112  137.0  0.000000  0.000000  0.007009  0.000000  0.0  0.0  81.0  0.359472
# 2113  140.0  0.000021  0.000000  0.006424  0.000000  0.0  0.0  83.0  0.200000
# 2114  140.0  0.003968  0.000000  0.003968  0.000000  0.0  0.0  80.0  0.200000
# 2123  142.0  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0  0.400000
#
# ...

# %%
outliers2.boxplot('ALTV',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
outliers3=df1[(df1.ALTV>lower)| (df1.ALTV<upper)]
outliers3
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2119  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2120  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2121  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2123  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
outliers3.boxplot('ALTV',figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
outliers3.skew()
# Out:
# LB          0.322664
# AC          2.032003
# FM          6.749691
# UC          0.973685
# DL          2.008927
# DS          8.456689
# DP          6.453124
# ASTV        0.054887
# MSTV        4.141709
# ALTV        2.979526
# MLTV        3.560883
# Width       0.498480
# Tendency   -0.500473
# NSP         1.825387
# dtype: float64

# %%
outliers3.kurt()
# Out:
# LB           11.379380
# AC           12.648866
# FM           94.380977
# UC           10.136133
# DL           12.848243
# DS          228.891263
# DP           76.725970
# ASTV          4.410606
# MSTV         44.006776
# ALTV         15.897009
# MLTV         56.515689
# Width         5.728450
# Tendency      1.468820
# NSP           3.746833
# dtype: float64

# %%
outliers2.skew()
# Out:
# LB          -0.272902
# AC          11.914557
# FM          12.438710
# UC          -0.594178
# DL          10.243136
# DS           7.314774
# DP          10.658491
# ASTV        -1.183926
# MSTV         8.368996
# ALTV         0.992719
# MLTV        13.581830
# Width        3.258744
# Tendency    -0.771462
# NSP          0.282082
# dtype: float64

# %%
outliers2.kurt()
# Out:
# LB           -0.795688
# AC          172.217034
# FM          154.606239
# UC            5.511507
# DL          116.141056
# DS          158.497652
# DP          200.679777
# ASTV         16.414653
# MSTV        104.403659
# ALTV         12.323377
# MLTV        218.984463
# Width        25.815528
# Tendency      1.028093
# NSP          -1.007871
# dtype: float64

# %%
outliers.skew()
# Out:
# LB         -0.484126
# AC          0.363476
# FM          1.692855
# UC          2.918044
# DL          2.399564
# DS          0.000000
# DP          0.000000
# ASTV       -2.297463
# MSTV        0.373497
# ALTV        2.340295
# MLTV        1.995160
# Width       0.045516
# Tendency    0.000000
# NSP         3.161823
# dtype: float64

# %%
outliers.kurt()
# Out:
# LB         -2.276774
# AC         -1.047818
# FM          1.211207
# UC          8.852146
# DL          5.956860
# DS          0.000000
# DP          0.000000
# ASTV        6.127524
# MSTV       -1.113174
# ALTV        5.178211
# MLTV        5.241324
# Width      -0.723260
# Tendency   -2.571429
# NSP         9.997905
# dtype: float64

# %%
df1.hist('LB',figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'LB'}>]], dtype=object)

# %%
df1.hist('ALTV',figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'ALTV'}>]], dtype=object)

# %%
import seaborn as sns
fig=plt.figure(figsize=(10,10))
sns.heatmap(df[['ALTV','AC','FM','UC','LB']].corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>
